# %% [markdown]
# <a href="https://colab.research.google.com/github/silvatria/pembelajaran-mesin-254107023001/blob/main/JS03_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Langkah 1 - Load Image
from PIL import Image

img = Image.open('img/Lenna.png')
img.show() # tampilkan gambar
display(img) # metode alternatif tampilkan gambar

# Langkah 2 - Ekstrak Fitur
# Ekstrak setiap channel red, green, blue
r, g, b = img.split()

# Cek panjang ukuran channel red
print(len(r.histogram()))

# Cetak fitur histogram pada channel red
print(r.histogram())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_781/1334176493.py in <cell line: 0>()
#       2 from PIL import Image
#       3
# ----> 4 img = Image.open('img/Lenna_(test_image).png')
#       5 img.show() # tampilkan gambar
#       6 display(img) # metode alternatif tampilkan gambar
#
# /usr/local/lib/python3.13/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/Lenna_(test_image).png'
